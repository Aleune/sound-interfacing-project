# %%
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt

from SoundProject.SoundCard import SoundCard
from SoundProject.SignalAnalysisDistSpeakers import SignalAnalysisDistSpeakers
from SoundProject.SignalAnalysisPendulum import SignalAnalysisPendulum
from Utils.utils import low_pass, high_pass

# %% [markdown]
# ### Analysis of pendulum data

# %%
data = np.loadtxt("Data/penduleData_10sec_2.txt")
dataFiltered = low_pass(data, 2100, 44100)
dataFiltered = high_pass(dataFiltered, 1900, 41000)

# %%
analysis = SignalAnalysisPendulum(data)
analysisFiltered = SignalAnalysisPendulum(dataFiltered)

# %%
analysis.plot_signal()
analysisFiltered.plot_signal()

# %%
analysis.plot_psd()
analysisFiltered.plot_psd()

# %%
analysis.plotDistance(2000)
